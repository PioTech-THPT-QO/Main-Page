# %% [markdown]
# <h1 style='text-align:center'>C.QO vs PioTech</h1>
#
# <h3 style='text-align:center'>(ĐỀ THI DÀNH CHO C.QO)</h3>
#
# ---
# <center>
#
# | Tên bài | Tên tệp chương trình | Tên tệp dữ liệu vào | Tên tệp dữ liệu ra | Thời gian chạy một test
# | :---: | :---: | :---: | :---: | :---: |
# | Fibonacci Prime | FBPR.* | FBPR.INP | FBPR.OUT | 1s |
# | name | file.* | file.inp | file.out | 1s |
# | Con Nhện | SPIDER.* | SPIDER.INP | SPIDER.OUT | 1s |
# | Bước Chân Nhiệm Màu | FLFW.* | FLFW.INP | FLFW.OUT | 1s |
#
# </center>
# *Chú ý: Dấu * được thay thế bởi pas, java, cpp hoặc py phụ thuộc vào ngôn ngữ lập trình được sử dụng.*
#
# ## Bài 1: Fibonacci Prime
# Dãy số Fibonacci là dãy vô hạn các số bắt đầu bằng 1 và 1 (hoặc 0 và 1), các phần tử sau luôn bằng tổng hai phần tử trước nó.
#
# Công thức truy hồi của dãy Fibonacci là:
# ![Ảnh công thức dãy Fibonacci](https://wikimedia.org/api/rest_v1/media/math/render/svg/6693d2c78bc8132bb9b65be861148ca574a738ef)
#
# Số Fibonacci nguyên tố là số thuộc dãy Fibonacci và chỉ có hai ước là 1 và chính nó. VD: 2, 3, 5, 13 là các số Fibonacci nguyên tố.
#
# Cho một số nguyên dương *N*, hãy kiểm tra xem liệu *N* có phải là số **Fibonacci nguyên tố** hay không.
#
# ### Mô tả đầu vào:
#
# - Đọc từ tệp **FBPR.INP** một số nguyên dương duy nhất là *N*. (0 ≤ *N* ≤ 10^9)
#
# ### Mô tả đầu ra:
#
# - Ghi ra tệp **FBPR.OUT** một số duy nhất là **1** nếu *N* nhập là số Fibonacci nguyên tố, ngược lại, ghi **0**.
#
# ### Rằng buộc:
# - Có 40 % số test *N* < 10^6.
# - Có 40 % số test 10^6 < *N* < 10^12.
# - Có 20 % số test *N* > 10^15.
#
# | FBPR.INP | FBPR.OUT|
# |:--------|:---------|
# | 9 | 0 |
# | 165580141 | 1 |
#
# ## Bài 3: Con Nhện
#
# Một lưới ô vuông *N* x *M* (số hàng *M* < *N* số cột). Một con nhện cần leo từ điểm A lên điểm B (như hình vẽ)(hình vẽ minh hoạ M và N). Mỗi lần leo chỉ bò men theo các **cạnh** của ô: lên đúng một bậc hoặc sang phải (**có thể nhiều ô**). Hỏi có bao nhiêu cách để con nhện lên được B?
#
# ![Ảnh Nam](https://i.ibb.co/bvJNjyS/nam.png)
#
# ## Bài 4: Bước Chân Nhiệm Màu
#
# Nhà Dương có cái cầu thang gồm *N* bậc và mỗi bậc được đánh số như hình vẽ.
# ![Ảnh cách đánh số bậc thang](https://i.ibb.co/TTG1bkW/image.png)
#
# Dương đứng ở chân cầu thang, muốn trèo lên đỉnh cầu thang. Số bước cầu thang Dương có thể thực hiện mỗi lần là **một hoặc hai bước**. Hãy giúp Dương tính số cách để leo lên đỉnh cầu thang.
#
# ### Mô tả đầu vào:
#
# - Đọc từ tệp **FLFW.INP** một số nguyên dương duy nhất là *N*. (*N* ≤ 10^3)
#
# ### Mô tả đầu ra:
#
# - Ghi ra tệp **FLFW.OUT** một số duy nhất là số cách để leo lên đỉnh cầu thang.
#
# ### Rằng buộc:
#
# - Có 20 % số test *N* < 10^2.
# - Có 80 % số test 10^2 *N* < 10^3.
#
# | FLFW.INP | FLFW.OUT | Giải thích |
# |:--------|:---------| :-----------|
# | 2 | 2 | Có hai cách để leo lên bậc thứ 2: <ul> <li> 0→1→2 </li> <li> 0→2 </li> </ul> |
# | 4 | 5 | Có cách để leo lên bậc thứ 4: <ul> <li> 0→1→2→3→4 </li> <li> 0→1→2→4 </li> <li> 0→1→3→4 </li> <li> 0→2→3→4 </li><li> 0→2→4 </li></ul>|

# %% [markdown]
# ### Heading
#
# # H1
# ## H2
# ### H3
#
# ### Bold
#
# **bold text**
#
# ### Italic
#
# *italicized text*
#
# ### Blockquote
#
# > blockquote
#
# ### Ordered List
#
# 1. First item
# 2. Second item
# 3. Third item
#
# ### Unordered List
#
# - First item
# - Second item
# - Third item
#
# ### Code
#
# `code`
#
# ### Horizontal Rule
#
# ---
#
# ### Link
#
# [Markdown Guide](https://www.markdownguide.org)
#
# ### Image
#
# ![alt text](https://www.markdownguide.org/assets/images/tux.png)
#
# ## Extended Syntax
#
# These elements extend the basic syntax by adding additional features. Not all Markdown applications support these elements.
#
# ### Table
#
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
#
# ### Fenced Code Block
#
# ```
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "age": 25
# }
# ```
#
# ### Footnote
#
# Here's a sentence with a footnote. [^1]
#
# [^1]: This is the footnote.
#
# ### Heading ID
#
# ### My Great Heading {#custom-id}
#
# ### Definition List
#
# term
# : definition
#
# ### Strikethrough
#
# ~~The world is flat.~~
#
# ### Task List
#
# - [x] Write the press release
# - [ ] Update the website
# - [ ] Contact the media
